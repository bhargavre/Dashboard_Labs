# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/")

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US" xmlns:fb="http://ogp.me/ns/fb#" xmlns:addthis="http://www.addthis.com/help/api-spec"  prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <![endif]-->
# <!--[if IE 8]>
# <html class="ie ie8" lang="en-US" xmlns:fb="http://ogp.me/ns/fb#" xmlns:addthis="http://www.addthis.com/help/api-spec"  prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <![endif]-->
# <!--[if !(IE 7) | !(IE 8)  ]><!-->
# <html lang="en-US" xmlns:fb="ht

# %%
s = BeautifulSoup(r.text, 'html.parser')

# %%
result = s.find_all('td',attrs={'valign':'top'})

# %%
len(result)
# Out:
# 186

# %%
a
# Out:
# <td valign="top" width="45">Sr. No</td>

# %%
a.text
# Out:
# 'Sr. No'

# %%
b = []
j=0
for i in range(0,len(result),3):
    b.append([])
    b[j].append(result[i].text)
    b[j].append(result[i+1].text)
    b[j].append(result[i+2].text)
    j=j+1

# %%
import pandas as pd
rank = pd.DataFrame(b)
rank.to_csv('rank.csv',index=False,header=False)

# %% [markdown]
# the Above code is to import a csv file of the MSIS college rankings.

# %%
r = requests.get("https://www.scu.edu/business/ms-information-systems/")

# %%
s = BeautifulSoup(r.text, 'html.parser')

# %%
result = s.find_all('div', attrs={'class':'panel-body panel-with-caret'})

# %%
len(result)
# Out:
# 2

# %%
result[0].text
# Out:
# '2017 Fall MSIS entering class profile \n\nAverage age : 25\nWomen : 61%\nAverage undergraduate : GPA 3.26\nAverage GMAT or GRE \xa0: 644 / 307\nAverage TOEFL : 102\n\n\xa0'

# %%
result[0].ul.li


#result[0].li.text
# Out:
# <li><strong>Average age</strong> : 25</li>

# %%
import pandas as pd
columnheader = ['Classification', 'Value']
classprofile = pd.DataFrame(b)
classprofile.to_csv('classprofile.csv',index=False,header=columnheader)

# %%
r = requests.get("http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html")

# %%
s = BeautifulSoup(r.text, 'html.parser')

# %%
result = s.find_all('table', attrs={'class':'wikitable'})

# %%
len(result)
# Out:
# 1

# %%
result[0].tr
# Out:
# <tr class="odd">
# <th> Category </th>
# <th> Santa Clara University </th>
# <th> San Jose State University </th>
# <th> University of San Francisco</th>
# </tr>

# %%
b = []
#j=0
#for i in range(len(result)):
#    print (result[i].text)
data = result[0].text
d = data.split('\n\n\n')

for i in range(len(d)):
    b.append(d[i].split('\n'))



  #  b.append([])
   # b[j].append(result[i].ul.text)
   # b[j].append(result[i+1].text)
    #b[j].append(result[i+2].text)
    #j=j+1

# %%
import pandas as pd
scucomparision = pd.DataFrame(b)
scucomparision.to_csv('scucomparision.csv',index=False,header=False)

# %%
import pdfquery

# %%
r = requests.get("https://www.forbes.com/colleges/santa-clara-university/")

# %%
s = BeautifulSoup(r.text, 'html.parser')

# %%
result = s.find_all('div', attrs={'class':'ataglanz fleft'})

# %%
len(result)
# Out:
# 1

# %%
result[0]
# Out:
# <div class="ataglanz fleft">
# <h6>At a Glance</h6>
# <ul>
# <li>Student Population: <b>8,680</b></li>
# <li>Undergraduate Population: <b>5,385</b></li>
# <li>Student to Faculty Ratio<sup>a</sup>: <b>12</b></li>
# <li>Total Annual Cost<sup>c</sup>: <b>$63,666</b></li>
# <li>In-State Tuition<sup>c</sup>: <b>$45,300</b></li>
# <li>Out-of-State Tuition<sup>c</sup>: <b>$45,300</b></li>
# <li>Percent on Financial Aid<sup>d</sup>: <b>72%</b></li>
# <li>Average Grant Aid Received (FT/First-Time): <b>$22,303</b></li>
# <li>Percent Admitted<sup>e</sup>: <b>49%</b></li>
# <li>SAT Composite Range<sup>f</sup>: <b>1210-1400</b></li>
# <li>ACT Composite Range<sup>f</sup>: <b>27-32</b></li>
# </ul>
# </div>

# %%
result[0].text
# Out:
# '\nAt a Glance\n\nStudent Population: 8,680\nUndergraduate Population: 5,385\nStudent to Faculty Ratioa: 12\nTotal Annual Costc: $63,666\nIn-State Tuitionc: $45,300\nOut-of-State Tuitionc: $45,300\nPercent on Financial Aidd: 72%\nAverage Grant Aid Received (FT/First-Time): $22,303\nPercent Admittede: 49%\nSAT Composite Rangef: 1210-1400\nACT Composite Rangef: 27-32\n\n'

# %%
b = []
#j=0
#for i in range(len(result)):
#    print (result[i].text)
data = result[0].text
d = data.splitlines()

for i in range(len(d)):
    b.append(d[i].split(':'))

b

  #  b.append([])
   # b[j].append(result[i].ul.text)
   # b[j].append(result[i+1].text)
    #b[j].append(result[i+2].text)
    #j=j+1
# Out:
# [[''],
#  ['At a Glance'],
#  [''],
#  ['Student Population', ' 8,680'],
#  ['Undergraduate Population', ' 5,385'],
#  ['Student to Faculty Ratioa', ' 12'],
#  ['Total Annual Costc', ' $63,666'],
#  ['In-State Tuitionc', ' $45,300'],
#  ['Out-of-State Tuitionc', ' $45,300'],
#  ['Percent on Financial Aidd', ' 72%'],
#  ['Average Grant Aid Received (FT/First-Time)', ' $22,303'],
#  ['Percent Admittede', ' 49%'],
#  ['SAT Composite Rangef', ' 1210-1400'],
#  ['ACT Composite Rangef', ' 27-32'],
#  ['']]

# %%
import pandas as pd
scustats = pd.DataFrame(b)
scustats.to_csv('scustats.csv',index=False,header=False)

# %%
r = requests.get("https://www.scu.edu/business/undergraduates/community/global-fellows/placements/by-major/")

# %%
s = BeautifulSoup(r.text, 'html.parser')

# %%
result = s.find_all('div', attrs={'class':'grid-item grid-01'})

# %%
len(result)
# Out:
# 7

# %%
b = []
#j=0
#for i in range(len(result)):
#    print (result[i].text)
data = result[0].text
d = data.splitlines()



for i in range(len(d)):
    b.append(d[i].split('('))

b

  #  b.append([])
   # b[j].append(result[i].ul.text)
   # b[j].append(result[i+1].text)
    #b[j].append(result[i+2].text)
    #j=j+1
# Out:
# [[''],
#  ['Business'],
#  [''],
#  ['Aarti Home for Girls\xa0', 'India)'],
#  ['AHA Bolivia\xa0', 'Bolivia)Marketing, Retail Management preferred'],
#  ['Bolivia 4WARD "Khan Academy"\xa0', 'Bolivia)'],
#  ['Bright Generation\xa0', 'Ghana)'],
#  ['Destiny Foundation\xa0', 'India)Marketing preferred'],
#  ['Franklin Templeton ', 'India)Finance, OMIS, Marketing preferred'],
#  ['Prafull Oorja\xa0', 'India)'],
#  ['IIEE\xa0', 'Indonesia)Economics preferred'],
#  ['Asila Luxury ', 'Morocco)'],
#  ['Starfish International ', 'The Gambia)'],
#  ['Container Architecture and Mercado Verde ', 'Bolivia)']]

# %%
import pandas as pd
columnheader = ['Placement', 'Country']
globalplcmt = pd.DataFrame(b)
globalplcmt.to_csv('globalplcmt.csv',index=False,header=columnheader)

# %% [markdown]
# ### Effort into extracting data
#
# Understanding and learning how to use BeautifulSoup was a challenge, as I'm not technically sound with code so I had to google a lot of code to understand.
# Did a lot of trial and error initially, but then I understood and got the hang of it.
# I have cut a lot of lines that have errors and output so clean the data.
# The links that I have provided below (under sources) i used to study and understand about SCU MSIS in general.
# The links that i added below the dashboarads is the data i extracted using BeautifulSoup.

# %% [markdown]
# ### Objective:
# To make a dashboard about MSIS in SCU to attract potential students and recruiters.

# %% [markdown]
# ### Sources:
#
# Data Sources visited to make a sense out of claim and extract data I want to use:
#
# http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/
#
# https://en.wikipedia.org/wiki/List_of_Santa_Clara_University_people
#
# http://www.nacubo.org/Documents/EndowmentFiles/2016-Endowment-Market-Values.pdf
#
# https://www.paysa.com/cost-of-living/santa-clara-university-alumni-association--santa-clara,-ca--cl
#
# https://www.linkedin.com/school/10458916/alumni/
#
# https://www.payscale.com/research/US/Degree=Master_of_Information_Science_(MIS)/Salary
#
# http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html
#
# https://www.niche.com/colleges/santa-clara-university/
#
# https://www.masterstudies.com/MS-in-Information-Systems/USA/Leavey-School-of-Business/
#
# http://business-schools.startclass.com/d/a/California#main
#
# https://www.scu.edu/business/ms-information-systems/prospective-students/class-profile/
#
# https://www.scu.edu/business/ms-information-systems/
#
# https://www.masterstudies.com/MS-in-Information-Systems/USA/Leavey-School-of-Business/
#
# http://business-schools.startclass.com/l/8/Santa-Clara-University-Leavey-CA
#
#
#
# I tried to read up about MSIS, SCU and other colleges from the above sources to understand where SCU stands today and tried to visualise what information and how to represent it to attract potential students and requirements.

# %% [markdown]
# ### Dashboard 1
#
# Ranking and Class Profile

# %%
from IPython.display import Image
Image(filename ='C:\\Users\Bhargav Ravi\Downloads\quarter 3\Dashboards, visualization\lab 4\images\Dashboard 1.png')

# %% [markdown]
# I extracted data using Beautiful Soup from the below sources to make the first iteraration.
#
# http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/
#
# https://www.scu.edu/business/ms-information-systems/

# %% [markdown]
# What is good/bad about this dashboard?
#
# This Dashboard shows the relative ranking of SCU compared to all the other universities offerring MSIS. It can be seen that it is above average but the x-axis is very crowded. The Table that is included gives a typical class profile.
# What is missing is the placements and work potential.

# %% [markdown]
# ### Dashboard 2
#
# University Profile adn Global Placement Opportunities

# %%
from IPython.display import Image
Image(filename ='C:\\Users\Bhargav Ravi\Downloads\quarter 3\Dashboards, visualization\lab 4\images\Dashboard 2.png')

# %% [markdown]
# I extracted data about global placements from the below source
#
# https://www.scu.edu/business/undergraduates/community/global-fellows/placements/by-major/

# %% [markdown]
# What is good/bad about this dashboard?
#
# This Iteration shows the global placements of students. It gives an insight into the potential different global companies the students are/could be placed into. What is not here is the comparison between the other colleges that are in the same area with which i could make my claim even stronger.

# %% [markdown]
# ### Dashboard 3
#
# SCU-MSIS 'The best' trained and equipped for the industry

# %%
from IPython.display import Image
Image(filename ='C:\\Users\Bhargav Ravi\Downloads\quarter 3\Dashboards, visualization\lab 4\images\Dashboard 3.png')

# %% [markdown]
# I extracted the comparision data from the below source
#
# http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html
#
#
# What is good/bad about this final iteration?
#
# Dashboard 3 includes all of the above and the comparison with the school that is in the same region. It also cleans up the ratings chart by removing the x-axis legend which is really not useful to have.

# %% [markdown]
# ### Claim
#
# The MSIS graduates from Santa Clara University - Leavey School of Business are best trained and equipped to compete in the industry

# %% [markdown]
# ### Warrent
#
# From the final version we can gather small amounts of data which combine to form the entire claim.
#
# Class Profile:
# In general students who are accepted/graduate from SCU-MSIS are really good and have good scores.
#
# Placement across the globe:
# The MSIS course is taught so well, that students who graduate are not only picked by the local companies within the USA but also are picked from overseas across the world.
#
# Comparision with other university in the region:
# California is known for its really good weather and Bay Area. There are other universities like SJSU (San Jose State University) in the same region with same atmosphere and similar conditions. When we look at the comparision SCU stands out!!
#
# Rankings:
# Looking at the rankings especially for MSIS across the United States of America, SCU is doing really well and is playing along with Ivy colleges and other highly ranked colleges.

# %% [markdown]
# ### Qualifier
#
# Comparing SCU with other colleges that provide MSIS course and mainly the course in the region.

# %% [markdown]
# ### Conclusion
#
# Looking at the combination of the data we can see that there are good students that join and graduate from the MSIS program at SCU. Any college is great only because of amazing professors who teach students and make them as a full proof product.
# The ranking and university reputation is only due to the GPA, Companies that students join after graduation, Work that they do and how the students provide to making the society better.
#
# This is why I claim that MSIS graduates from SCU are best trained and equipped to compete in the industry.
