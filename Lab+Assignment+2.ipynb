# %% [markdown]
# import pandas

# %%
trial = pandas.read_excel("Information is Beautiful- Data Breaches (public).xlsx")

# %%
trial
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
# to change the years from 1,2 to actual years
trial.loc[trial.YEAR==0,'YEAR']=2004
trial.loc[trial.YEAR==1,'YEAR']=2005
trial.loc[trial.YEAR==2,'YEAR']=2006
trial.loc[trial.YEAR==3,'YEAR']=2007
trial.loc[trial.YEAR==4,'YEAR']=2008
trial.loc[trial.YEAR==5,'YEAR']=2009
trial.loc[trial.YEAR==6,'YEAR']=2010
trial.loc[trial.YEAR==7,'YEAR']=2011
trial.loc[trial.YEAR==8,'YEAR']=2012
trial.loc[trial.YEAR==9,'YEAR']=2013
trial.loc[trial.YEAR==10,'YEAR']=2014
trial.loc[trial.YEAR==11,'YEAR']=2015
trial.loc[trial.YEAR==12,'YEAR']=2016
trial.loc[trial.YEAR==13,'YEAR']=2017
trial.loc[trial.YEAR==14,'YEAR']=2018

# %%
trial
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
trial.loc[(trial['DATA SENSITIVITY']==20),'DATA SENSITIVITY']='SSN/Personal Details'
trial.loc[(trial['DATA SENSITIVITY']==300),'DATA SENSITIVITY']='Credit card Information'
trial.loc[(trial['DATA SENSITIVITY']==4000),'DATA SENSITIVITY']='Email Passwords/Health Records'
trial.loc[(trial['DATA SENSITIVITY']==50000),'DATA SENSITIVITY']='Full Bank Account Details'
trial.loc[(trial['DATA SENSITIVITY']==1),'DATA SENSITIVITY']='Just Email Addresses/Online Information'

# %%
trial
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
del trial['UNUSED']
del trial['UNUSED.1']
del trial['Exclude']
del trial['Unnamed: 13']

# %%
trial
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
del trial['alternative name']
del trial['story']
del trial['interesting story']
del trial['NO OF RECORDS STOLEN']
del trial['1st source link']
del trial['2nd source link']
del trial['3rd source']
del trial['source name']

# %%
trial
# Out:
#                                              Entity  \
# 0                                               NaN
# 1                                               AOL
# 2                         Automatic Data Processing
# 3                                   Ameritrade Inc.
# 4                                         Citigroup
# 5                       Cardsystems Solutions Inc.
# 6                                   Hewlett Packard
# 7                        Countrywide Financial Corp
# 8                                              KDDI
# 9                        T-Mobile, Deutsche Telecom
# 10                                              AOL
# 11                           US Dept of Vet Affairs
# 12                                    Texas Lottery
# 13     City and Hackney Teaching Primary Care Trust
# 14                                          Gap Inc
# 15                                     Compass Bank
# 16                                      Monster.com
# ...

# %%
#remove the 0th row
trial1 = trial.iloc[1:]

# %%
trial1
# Out:
#                                              Entity  YEAR records lost  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# ...

# %%
trial1.loc[(trial['DATA SENSITIVITY']=='20'),'DATA SENSITIVITY']='SSN/Personal Details'
trial1.loc[(trial['DATA SENSITIVITY']=='300'),'DATA SENSITIVITY']='Credit card Information'
trial1.loc[(trial['DATA SENSITIVITY']=='4000'),'DATA SENSITIVITY']='Email Passwords/Health Records'
trial1.loc[(trial['DATA SENSITIVITY']=='50000'),'DATA SENSITIVITY']='Full Bank Account Details'
trial1.loc[(trial['DATA SENSITIVITY']=='1'),'DATA SENSITIVITY']='Just Email Addresses/Online Information'
# Out:
# C:\Users\Bhargav Ravi\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Bhargav Ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Bhargav Ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %%
trial1
# Out:
#                                              Entity  YEAR records lost  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# ...

# %%
trial1 = trial1.rename(columns={'YEAR':'Year','records lost':'Records Lost','ORGANISATION':'Organization','METHOD OF LEAK':'Method of Leak','DATA SENSITIVITY':'Data Sensitivity'})

# %%
trial1
# Out:
#                                              Entity  Year Records Lost  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# ...

# %%
#renamed the columns to right format.
#before renaming, fixed the data error in the data sensitivity column

# %%
#separating number of records lost with comma
trial1['Records Lost'] = trial1.apply(lambda x: "{:,}".format(x['Records Lost']), axis=1)
print(trial1.head())
# Out:
#                         Entity  Year Records Lost Organization  \
# 1                          AOL  2004   92,000,000          web
# 2    Automatic Data Processing  2005      125,000    financial
# 3              Ameritrade Inc.  2005      200,000    financial
# 4                    Citigroup  2005    3,900,000    financial
# 5  Cardsystems Solutions Inc.   2005   40,000,000    financial
#
#          Method of Leak                         Data Sensitivity
# 1            inside job  Just Email Addresses/Online Information
# 2         poor security                     SSN/Personal Details
# 3  lost / stolen device                     SSN/Personal Details
# 4  lost / stolen device                  Credit card Information
# 5                hacked                  Credit card Information

# %%
trial1
# Out:
#                                              Entity  Year   Records Lost  \
# 1                                               AOL  2004     92,000,000
# 2                         Automatic Data Processing  2005        125,000
# 3                                   Ameritrade Inc.  2005        200,000
# 4                                         Citigroup  2005      3,900,000
# 5                       Cardsystems Solutions Inc.   2005     40,000,000
# 6                                   Hewlett Packard  2006        200,000
# 7                        Countrywide Financial Corp  2006      2,600,000
# 8                                              KDDI  2006      4,000,000
# 9                        T-Mobile, Deutsche Telecom  2006     17,000,000
# 10                                              AOL  2006     20,000,000
# 11                           US Dept of Vet Affairs  2006     26,500,000
# 12                                    Texas Lottery  2007         89,000
# ...

# %%
trial1.to_csv(“assignment2.csv”)
# Out:
#   File "<ipython-input-24-0a1a86ddfbfb>", line 1
#     trial1.to_csv(“assignment2.csv”)
#                              ^
# SyntaxError: invalid character in identifier

# %%
trial1.to_excel("assignment2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-57e4faab571f> in <module>()
# ----> 1 trial1.to_excel("assignment2.xlsx")
#
# NameError: name 'trial1' is not defined

# %%
trial1.to_excel("assignment2.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-57e4faab571f> in <module>()
# ----> 1 trial1.to_excel("assignment2.xlsx")
#
# NameError: name 'trial1' is not defined

# %%
trial1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a534e8dac603> in <module>()
# ----> 1 trial1
#
# NameError: name 'trial1' is not defined

# %%
# %%HTML
# https://public.tableau.com/views/labassignment2/Dashboard2?:embed=y&:display_count=yes&publish=yes
# Out:
# <!DOCTYPE html>
#   <!--[if IEMobile 7]><html class="no-js ie iem7" lang="en" dir="ltr"><![endif]-->
#   <!--[if lte IE 6]><html class="no-js ie lt-ie9 lt-ie8 lt-ie7" lang="en" dir="ltr"><![endif]-->
#   <!--[if (IE 7)&(!IEMobile)]><html class="no-js ie lt-ie9 lt-ie8" lang="en" dir="ltr"><![endif]-->
#   <!--[if IE 8]><html class="no-js ie lt-ie9" id="ng-app" ng-app="vizhub" ng-csp lang="en" dir="ltr"><![endif]-->
#   <!--[if IE 9]><html class="no-js ie ie9 lte-ie9" id="ng-app" ng-app="vizhub" ng-csp lang="en" dir="ltr"><![endif]-->
#   <!--[if (gte IE 9)|(gt IEMobile 7)]><html class="no-js ie" id="ng-app" ng-app="vizhub" ng-csp lang="en" dir="ltr" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video#"><![endif]-->
# ...

# %% [markdown]
# Version 1: https://public.tableau.com/views/labassignment2/Dashboard2?:embed=y&:display_count=yes&publish=yes
#
# Advantages:
#
# -Shows trend based on data sensitivity
#
#
# Disadvantages:
#
# -Does not bring out the overall trend of the number of breaches.
#
# -The almost flat graphs don’t highlight the gravity of the situation.

# %% [markdown]
# Version 2: https://public.tableau.com/views/labassignment2/Dashboard3?:embed=y&:display_count=yes
#
# Advantages:
#
# -Shows trend based on data sensitivity.
#
# -The large spikes show that the situation needs attention.
#
# Disadvantages:
#
# -Too cluttered.
#
# -Not all the years are shown so cannot draw conclusions about the trend of breaches.
#
# -Title does not show or provoke any action.

# %% [markdown]
# Version 3: https://public.tableau.com/views/labassignment2/Dashboard1?:embed=y&:display_count=yes
#
# Advantages:
#
# -Shows trend based on data sensitivity.
#
# -The large spikes show that the situation needs attention.
#
# -The trend is clearly visible over all the years.
#
# Disadvantages:
#
# -Cannot clearly see what data sensitivity is being exposed by the breaches.
#
# -Title does not show or provoke any action.

# %% [markdown]
# Final Version: https://public.tableau.com/views/labassignment2/Dashboard4?:embed=y&:display_count=yes
#
# Advantages:
#
# -Shows trend based on data sensitivity.
#
# -The large spikes show that the situation needs attention.
#
# -The trend is clearly visible over all the years.
#
# -Shows which type of data leak in on the rise and which on the decline.
#
# -Title clearly defines the problem and the action that needs to be taken.

# %% [markdown]
# Conclusion:
#
# The graph clearly shows that
#
# -	Whenever there have been major data breeches, actions have been taken to curtail it.
#
# -	SSN and personal information has been the most exposed data through the breaches over the years.
#
# -	Though SSN and personal data leak has seen a decline in the last year, email passwords and full bank details are seeing a rise.
#
# Immediate action needs to be taken to
#
# -	Continue to keep SSN/personal information secure.
#
# -	secure email passwords.
#
# -	secure bank details.
#
#
# In conclusion, security breaches for certain kinds of data leaks are becoming more severe.
